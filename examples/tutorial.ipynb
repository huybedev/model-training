# %% [markdown]
# <a href="https://colab.research.google.com/github/huybedev/model-training/blob/main/examples/tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Setup

# %%
# !uv pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.4.52 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 43.0/112.6 GB disk)

# %% [markdown]
# # Train

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="pjP9SxrNAvdqKiKhEErR")
project = rf.workspace("huys-workspace-sz4ni").project("yolo-roof-damaged-v2-j0ebo")
version = project.version(3)
dataset = version.download("yolov11")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.9/207.9 kB 12.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 7.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 21.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 91.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 142.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.13.0.92
#     Uninstalling opencv-python-headless-4.13.0.92:
#       Successfully uninstalled opencv-python-headless-4.13.0.92
#   Attempting uninstall: idna
#     Found existing installation: idna 3.13
#     Uninstalling idna-3.13:
#       Successfully uninstalled idna-3.13
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to YOLO-roof-damaged-v2-3 in yolov11:: 100%|██████████| 763/763 [00:00<00:00, 9878.27it/s]

# %%
# Train YOLOV11n-seg for 300 epochs
# !yolo train model=yolo11n-seg.pt data=/content/YOLO-roof-damaged-v2-3/data.yaml epochs=300 imgsz=640
# Out:
# ...
# Ultralytics 8.4.52 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %% [markdown]
# # Validate the best model

# %%
from ultralytics import YOLO

# Load the best trained model
model_path = '/content/runs/segment/train/weights/best.pt'
best_model = YOLO(model_path)

print(f'Loaded best model from: {model_path}')
# Out:
# Loaded best model from: /content/runs/segment/train/weights/best.pt

# %%
# Validate the best model
metrics = best_model.val(data=f"/content/YOLO-roof-damaged-v2-3/data.yaml", imgsz=640)

print('\nValidation Metrics:')
print(f"  mAP50-95: {metrics.box.map}")
print(f"  mAP50: {metrics.box.map50}")
print(f"  mAP50-95 (masks): {metrics.seg.map}")
print(f"  mAP50 (masks): {metrics.seg.map50}")
# Out:
# Ultralytics 8.4.52 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLO11n-seg summary (fused): 114 layers, 2,835,543 parameters, 0 gradients, 9.6 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 981.5±532.2 MB/s, size: 19.3 KB)
# val: Scanning /content/YOLO-roof-damaged-v2-3/valid/labels.cache... 76 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 76/76 10.6Mit/s 0.0s
# val: /content/YOLO-roof-damaged-v2-3/valid/images/L12_jpg.rf.9a77fcdd1da99e27a95fab7f1253de3f.jpg: 1 duplicate labels removed
# val: /content/YOLO-roof-damaged-v2-3/valid/images/istockphoto-496444009-612x612_jpg.rf.a7199b9dcee18d0eec9e50f787c43546.jpg: 1 duplicate labels removed
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.2it/s 4.0s
#                    all         76        350      0.576      0.487      0.478      0.288       0.56      0.477      0.457      0.227
# ...

# %%
from ultralytics import YOLO

# Load a modelư
model = YOLO('/content/runs/segment/train/weights/best.pt')  # load a pretrained model (recommended for training)

# Use the model
results = model('https://betaviet.vn/wp-content/uploads/2024/11/nguyen-nhan-nut-tuong-va-nhung-cach-xu-ly-can-biet-1jpg-1690357723541-2.jpg', save=True)  # predict on an image
# Out:
# WARNING ⚠️ Video stream unresponsive, please check your IP camera connection.
# WARNING ⚠️ Video stream unresponsive, please check your IP camera connection.
# WARNING ⚠️ Video stream unresponsive, please check your IP camera connection.
# WARNING ⚠️ Video stream unresponsive, please check your IP camera connection.
# WARNING ⚠️ Video stream unresponsive, please check your IP camera connection.
# WARNING ⚠️ Video stream unresponsive, please check your IP camera connection.
# WARNING ⚠️ Video stream unresponsive, please check your IP camera connection.
# WARNING ⚠️ Video stream unresponsive, please check your IP camera connection.
# WARNING ⚠️ Video stream unresponsive, please check your IP camera connection.
# WARNING ⚠️ Video stream unresponsive, please check your IP camera connection.
# WARNING ⚠️ Video stream unresponsive, please check your IP camera connection.
# WARNING ⚠️ Video stream unresponsive, please check your IP camera connection.
#
# ...

# %% [markdown]
# ## Lưu kết quả Training về Google Drive

# %%
# Lưu kết quả vào drive

from google.colab import drive
drive.mount("/content/drive", force_remount=True)

# 1. Đặt tên thư mục gom cụm theo ý bạn muốn ở đây
ten_thu_muc_goc = "Roofdamage_YOLO11"

# 2. Tạo thư mục này trên Google Drive (tham số -p để tránh lỗi nếu thư mục đã có sẵn)
# !mkdir -p "/content/drive/MyDrive/{ten_thu_muc_goc}"

# 3. Copy chính xác 2 thư mục mục tiêu vào bên trong thư mục vừa tạo
# !cp -r /content/YOLO-roof-damaged-v2-3 "/content/drive/MyDrive/{ten_thu_muc_goc}/"
# !cp -r /content/runs "/content/drive/MyDrive/{ten_thu_muc_goc}/"

print("🎉 Đã sao lưu thành công dữ liệu vào Google Drive!")
# Out:
# WARNING ⚠️ Video stream unresponsive, please check your IP camera connection.
# WARNING ⚠️ Video stream unresponsive, please check your IP camera connection.
# WARNING ⚠️ Video stream unresponsive, please check your IP camera connection.
# WARNING ⚠️ Video stream unresponsive, please check your IP camera connection.
# WARNING ⚠️ Video stream unresponsive, please check your IP camera connection.
# WARNING ⚠️ Video stream unresponsive, please check your IP camera connection.
# WARNING ⚠️ Video stream unresponsive, please check your IP camera connection.
# WARNING ⚠️ Video stream unresponsive, please check your IP camera connection.
# WARNING ⚠️ Video stream unresponsive, please check your IP camera connection.
# WARNING ⚠️ Video stream unresponsive, please check your IP camera connection.
# WARNING ⚠️ Video stream unresponsive, please check your IP camera connection.
# WARNING ⚠️ Video stream unresponsive, please check your IP camera connection.
# ...
